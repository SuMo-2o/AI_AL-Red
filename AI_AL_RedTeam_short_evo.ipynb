# %% [markdown]
# Plan: <br>
# 1. There is a small set of initial prompts in the same folder as this notebook, I'll start with it <br>
# 2. Then I will take EvoPrompt and extract only the pieces of code I need, adjusting them with ChatGPT <br>
# 3. Then I'll run the code on my initial set
